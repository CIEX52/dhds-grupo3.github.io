# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import sklearn.metrics as metrics
import sklearn.model_selection as model_selection
import sklearn.preprocessing as preprocessing
import sklearn.linear_model as linear_model

# %% [markdown]
# # importamos el dataset

# %%
data = pd.read_csv('/content/drive/MyDrive/DHDS/properatti2.csv')
data.shape
# Out:
# (98321, 21)

# %%
data.isnull().sum().sort_values()
# Out:
# property_type                     0
# price_aprox_usd                   0
# price_aprox_local_currency        0
# price                             0
# currency                          0
# country_name                      0
# place_with_parent_names           0
# place_name                        0
# state_name                        0
# title                             0
# description                       2
# surface_covered_m2             7478
# price_usd_surf_total          12863
# geonames_id                   16575
# surface_total_m2              31464
# price_usd_surf_covered        31713
# lat_lon                       40895
# lat                           40895
# lon                           40895
# rooms                         48917
# floor                         91571
# dtype: int64

# %%
data[['property_type', 'place_with_parent_names', 'currency', 'price', 'price_aprox_local_currency', 'price_aprox_usd',
      'price_usd_surf_covered', 'price_usd_surf_total', 'surface_total_m2', 'surface_covered_m2', 'rooms', 'floor']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98321 entries, 0 to 98320
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   property_type               98321 non-null  object
#  1   place_with_parent_names     98321 non-null  object
#  2   currency                    98321 non-null  object
#  3   price                       98321 non-null  float64
#  4   price_aprox_local_currency  98321 non-null  float64
#  5   price_aprox_usd             98321 non-null  float64
#  6   price_usd_surf_covered      66608 non-null  float64
#  7   price_usd_surf_total        85458 non-null  float64
#  8   surface_total_m2            66857 non-null  float64
#  9   surface_covered_m2          90843 non-null  float64
#  10  rooms                       49404 non-null  float64
#  11  floor                       6750 non-null   float64
# dtypes: float64(9), object(3)
# memory usage: 9.0+ MB
